# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv("dataset.csv")
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5664  0875-CABNR  Female              1      No         No      10
# 3648  9419-IPPBE  Female              0     Yes        Yes      51
# 209   1347-KTTTA    Male              0     Yes         No      64
# 5904  9402-CXWPL  Female              0      No         No      70
# 6837  6229-LSCKB    Male              1      No         No       6
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 5664          Yes            No     Fiber optic             No  ...
# 3648          Yes           Yes     Fiber optic             No  ...
# 209           Yes            No     Fiber optic             No  ...
# 5904          Yes           Yes     Fiber optic             No  ...
# 6837          Yes            No     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 5664              Yes          No          No             Yes  Month-to-month
# 3648              Yes          No          No             Yes        One year
# 209               Yes         Yes         Yes             Yes        One year
# 5904               No          No         Yes             Yes        One year
# 6837               No          No         Yes              No  Month-to-month
#
#      PaperlessBilling            PaymentMethod MonthlyCharges  TotalCharges  \
# 5664              Yes  Credit card (automatic)          84.60        865.55
# 3648              Yes         Electronic check          90.15       4554.85
# 209               Yes  Credit card (automatic)         102.45        6654.1
# 5904               No         Electronic check          98.90        6838.6
# 6837              Yes         Electronic check          79.70         497.6
#
#      Churn
# 5664   Yes
# 3648    No
# 209     No
# 5904    No
# 6837    No
#
# [5 rows x 21 columns]

# %%
df.drop('customerID',axis='columns',inplace=True)
df.sample(5)
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object
